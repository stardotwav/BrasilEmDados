# %%
#Importações de módulos necessários
import pandas as pd

# %%
path1 = "./Dados/Covid/HIST_PAINEL_COVIDBR_2020_Parte1_22ago2021.csv"
path2 = "./Dados/Covid/HIST_PAINEL_COVIDBR_2020_Parte2_22ago2021.csv"
path3= "./Dados/Covid/HIST_PAINEL_COVIDBR_2021_Parte1_22ago2021.csv"
path4 = "./Dados/Covid/HIST_PAINEL_COVIDBR_2021_Parte2_22ago2021.csv"

path = [path1,path2,path3,path4]

df_from_each_file = (pd.read_csv(f,error_bad_lines=False,sep=';') for f in path)
df = pd.concat(df_from_each_file, ignore_index=True)
# Out:
# D:\Arquivos de programas(HD)\Python\Python39\lib\site-packages\pandas\core\reshape\concat.py:348: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   objs = list(objs)

# %%
df.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
# Remoção dos atributos não utilizados na analise
df = df.drop(columns=['coduf','codmun','codRegiaoSaude','nomeRegiaoSaude','Recuperadosnovos','emAcompanhamentoNovos','interior/metropolitana'])
df
# Out:
#                regiao estado municipio        data  semanaEpi  \
# 0              Brasil    NaN       NaN  2020-02-25          9
# 1              Brasil    NaN       NaN  2020-02-26          9
# 2              Brasil    NaN       NaN  2020-02-27          9
# 3              Brasil    NaN       NaN  2020-02-28          9
# 4              Brasil    NaN       NaN  2020-02-29          9
# ...               ...    ...       ...         ...        ...
# 2889029  Centro-Oeste     DF  Brasília  2021-08-18         33
# 2889030  Centro-Oeste     DF  Brasília  2021-08-19         33
# 2889031  Centro-Oeste     DF  Brasília  2021-08-20         33
# 2889032  Centro-Oeste     DF  Brasília  2021-08-21         33
# 2889033  Centro-Oeste     DF  Brasília  2021-08-22         34
#
#          populacaoTCU2019  casosAcumulado  casosNovos  obitosAcumulado  \
# 0             210147125.0             0.0           0                0
# 1             210147125.0             1.0           1                0
# ...

# %%
# Verificação de atributos 
df.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'data', 'semanaEpi',
#        'populacaoTCU2019', 'casosAcumulado', 'casosNovos', 'obitosAcumulado',
#        'obitosNovos'],
#       dtype='object')

# %%
#Verificação de data inicial e final
print(df["data"].min())
print(df["data"].max())
# Out:
# 2020-02-25
# 2021-08-22

# %%
#Comprovando que existe 545 dias únicos
print("Dias unicos no DF: "+ str(len(df[df['regiao'] == 'Brasil']['data'].unique())))
print("Número de linhas do datarame correspondente a data: "+str(len(df[df['regiao'] == 'Brasil']['data'])))
# Out:
# Dias unicos no DF: 545
# Número de linhas do datarame correspondente a data: 545

# %%
#As datas do município começam em '2020-03-27' e vão até '2021-08-22'
print(df[df['municipio'] == "Belo Horizonte"]["data"].min())
print(df[df['municipio'] == "Belo Horizonte"]["data"].max())
# Out:
# 2020-03-27
# 2021-08-22

# %%
df[(df['regiao'] == "Centro-Oeste") & (df['municipio'].isna()) & (df['estado'] == 'GO') & (df['casosAcumulado'] != 0 )]
# Out:
#                regiao estado municipio        data  semanaEpi  \
# 4125     Centro-Oeste     GO       NaN  2020-03-13         11
# 4126     Centro-Oeste     GO       NaN  2020-03-14         11
# 4127     Centro-Oeste     GO       NaN  2020-03-15         12
# 4128     Centro-Oeste     GO       NaN  2020-03-16         12
# 4129     Centro-Oeste     GO       NaN  2020-03-17         12
# ...               ...    ...       ...         ...        ...
# 2592653  Centro-Oeste     GO       NaN  2021-08-18         33
# 2592654  Centro-Oeste     GO       NaN  2021-08-19         33
# 2592655  Centro-Oeste     GO       NaN  2021-08-20         33
# 2592656  Centro-Oeste     GO       NaN  2021-08-21         33
# 2592657  Centro-Oeste     GO       NaN  2021-08-22         34
#
#          populacaoTCU2019  casosAcumulado  casosNovos  obitosAcumulado  \
# 4125            7018354.0             3.0           3                0
# 4126            7018354.0             3.0           0                0
# ...
